# %%
def choose_player():
    marker=''
  
    while marker not in ['X','O']:
        marker=input('Player_1 ,Choose X or O : ').upper()
    if marker=='X':
        return ('X','O')
    else:
        return ('O','X')
    
player_1,player_2=choose_player()

def play_game():
    
    display_board()
    place_on_board(board,current_player,1)
    
    
    
    

board=[' ',' ',' ',
       ' ',' ',' ',
       ' ',' ',' ']
    
   
    
def display_board():
    print(board[0] + ' | ' + board[1]+ ' | ' + board[2])
    print(board[3] + ' | ' + board[4]+ ' | ' + board[5])
    print(board[6] + ' | ' + board[7]+ ' | ' + board[8])
    




    
game_still_going=True 
winner=None
current_player=player_1


def check_for_winner():
    if winner==player_1:
        print('X won')
    elif winner==player_2:
        print('O won')
    
        

    
def place_on_board(game_board,marker,position):
    

    while game_still_going:
        
        position=int(input('Choose a position: '))
    
        position=(position)-1
        game_board[position]=current_player
        display_board()
        check_for_win()
        check_for_tie()
        flip_player()
    check_for_winner()
   


    
def check_for_win():
    
    check_rows()
def check_rows():
    global game_still_going
    row_1=board[0]==board[1]==board[2]!=' '
    row_2=board[3]==board[4]==board[5]!=' '
    row_3=board[6]==board[7]==board[8]!=' '
    if row_1 or row_2 or row_3:
            game_still_going=False
    global winner
    winner=current_player
    check_coloumns()
def check_coloumns():
    global game_still_going
    coloumn_1=board[0]==board[3]==board[6]!=' '
    coloumn_2=board[1]==board[4]==board[7]!=' '
    coloumn_3=board[2]==board[5]==board[8]!=' '
    if coloumn_1 or coloumn_2 or coloumn_3:
        game_still_going=False
    global winner
    winner=current_player
    
    check_diagonals()
def check_diagonals():
    global game_still_going
    diagonal_1=board[0]==board[4]==board[8]!=' '
    diagonal_2=board[2]==board[4]==board[6]!=' '
    if diagonal_1 or diagonal_2 :
        game_still_going=False
    global winner
    winner=current_player

    
def flip_player():
    
    global current_player
    if current_player==player_1:
        current_player=player_2
    else:
        current_player=player_1

def check_for_tie():
    pass
    
    
    

    
    
play_game()
# Out:
# Player_1 ,Choose X or O : X
#   |   |
#   |   |
#   |   |
